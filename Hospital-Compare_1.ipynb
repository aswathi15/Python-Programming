# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read the main Hospital compare excel
Hosp_compare_main = pd.read_excel("C://Users//Aswathi//Desktop//Hospital Compare_1.xlsx","Sheet2")

# %%
Hosp_compare_main
# Out:
#        Provider ID                                     Hospital Name  \
# 0            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 1            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 2            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 3            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 4            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 5            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 6            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 7            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 8            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 9            10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 10           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 11           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 12           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# ...

# %%
# read the Hospital national which has national rate related data
Hospital_national=pd.read_excel("C://Users//Aswathi//Desktop//Hospital Compare_National.xlsx")

# %%
Hospital_national
# Out:
#                                          Measure Name  \
# 0   A wound that splits open  after surgery on the...
# 1    Accidental cuts and tears from medical treatment
# 2   Acute Myocardial Infarction (AMI) 30-Day Morta...
# 3                Blood stream infection after surgery
# 4                Broken hip from a fall after surgery
# 5             Collapsed lung due to medical treatment
# 6                                 Death rate for CABG
# 7   Death rate for chronic obstructive pulmonary d...
# 8                      Death rate for stroke patients
# 9   Deaths among Patients with Serious Treatable C...
# 10           Heart failure (HF) 30-Day Mortality Rate
# 11          Perioperative Hemorrhage or Hematoma Rate
# 12               Pneumonia (PN) 30-Day Mortality Rate
# 13  Postoperative Acute Kidney Injury Requiring Di...
# 14             Postoperative Respiratory Failure Rate
# 15                                     Pressure sores
# ...

# %%
# read the state excel, which has the states and their corresponding measures and their national rate comparison
hospital_state = pd.read_excel("C://Users//Aswathi//Desktop//Hospital Compare_State.xlsx")

# %%
hospital_state
# Out:
#      State                                       Measure Name  \
# 0       AK  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 1       AL  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 2       AR  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 3       AS  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 4       AZ  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 5       CA  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 6       CO  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 7       CT  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 8       DC  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 9       DE  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 10      FL  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 11      GA  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 12      GU  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 13      HI  Acute Myocardial Infarction (AMI) 30-Day Morta...
# ...

# %%
hospital_state_1=hospital_state.fillna(0)

# %%
hospital_state_1
# Out:
#      State                                       Measure Name  \
# 0       AK  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 1       AL  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 2       AR  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 3       AS  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 4       AZ  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 5       CA  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 6       CO  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 7       CT  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 8       DC  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 9       DE  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 10      FL  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 11      GA  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 12      GU  Acute Myocardial Infarction (AMI) 30-Day Morta...
# 13      HI  Acute Myocardial Infarction (AMI) 30-Day Morta...
# ...

# %%
# find the information about the states having Heart Failure related mortality rates better than the national rate
Heart_Failure_state =  hospital_state_1[hospital_state_1['Measure ID'] == 'MORT_30_HF'].sort_values(by="Number of Hospitals Better",ascending = False).head(10)

# %%
Heart_Failure_state_1=Heart_Failure_state[['State','Number of Hospitals Better']]

# %%
#display top 10 states who have the highest number of hospitals which are better than the national rate FOR Heart Failure
Heart_Failure_state_1
# Out:
#     State  Number of Hospitals Better
# 61     CA                        28.0
# 72     IL                        20.0
# 93     NY                        17.0
# 77     MA                        16.0
# 103    TX                        14.0
# 66     FL                        13.0
# 80     MI                        10.0
# 94     OH                        10.0
# 97     PA                         6.0
# 90     NJ                         5.0

# %%
final_1 = Heart_Failure_state_1.iloc[:,1:2]
print(final_1)
# Out:
#      Number of Hospitals Better
# 61                         28.0
# 72                         20.0
# 93                         17.0
# 77                         16.0
# 103                        14.0
# 66                         13.0
# 80                         10.0
# 94                         10.0
# 97                          6.0
# 90                          5.0

# %%
flist = list(final_1['Number of Hospitals Better'])

# %%
# get the count of the total number of hospitals in every state listed
Total_no_hospital_in_a_state = Hosp_compare_main.groupby('State')['Provider ID'].nunique().sort_values(ascending=False)

# %%
Total_no_hospital_in_a_state
# Out:
# State
# TX    410
# CA    343
# FL    187
# IL    180
# NY    171
# PA    171
# OH    169
# KS    137
# GA    133
# MN    131
# MI    131
# WI    126
# OK    122
# LA    121
# IN    120
# IA    116
# MO    112
# NC    107
# TN    107
# MS     95
# KY     94
# AL     91
# WA     91
# NE     90
# VA     86
# AZ     80
# CO     79
# AR     75
# NJ     66
# MA     63
# MT     62
# SC     60
# SD     60
# OR     60
# PR     53
# MD     49
# WV     49
# UT     45
# ND     44
# NM     41
# ID     41
# NV     35
# ME     33
# CT     31
# WY     28
# NH     26
# HI     23
# AK     22
# VT     14
# RI     11
# DC      8
# DE      7
# GU      2
# VI      2
# AS      1
# MP      1
# Name: Provider ID, dtype: int64

# %%
Total_no_hospital_in_a_state.plot()
plt.show()

# %%
Total_no_filtered = Total_no_hospital_in_a_state[['CA','IL','NY','MA','TX','FL','MI','OH','PA','NJ']]
print(Total_no_filtered)
# Out:
# State
# CA    343
# IL    180
# NY    171
# MA     63
# TX    410
# FL    187
# MI    131
# OH    169
# PA    171
# NJ     66
# Name: Provider ID, dtype: int64

# %%
flist1 = list(Total_no_filtered.values)

# %%
newList = []
for i in range(len(flist1)):
    newList.append(flist[i]/flist1[i])
print("Ratio=",newList)
#answers = pd.DataFrame({'Ratio': newList})

#print("Maxiumu value=",max(newList))
#print(newList.index(max(newList)))
#final_1.loc[]
#print(type(Total_no_filtered))
#State_best_healthcare_HF= Total_no_filtered.index[newList.index(max(newList))]
#print("State with the best Healthcare in Heart Attack=", State_best_healthcare_HF)
# Out:
# Ratio= [0.081632653061224483, 0.1111111111111111, 0.099415204678362568, 0.25396825396825395, 0.034146341463414637, 0.069518716577540107, 0.076335877862595422, 0.059171597633136092, 0.035087719298245612, 0.07575757575757576]

# %%
answers.index = ['CA','IL','NY','MA','TX','FL','MI','OH','PA','NJ']
answers
# Out:
#        Ratio
# CA  0.081633
# IL  0.111111
# NY  0.099415
# MA  0.253968
# TX  0.034146
# FL  0.069519
# MI  0.076336
# OH  0.059172
# PA  0.035088
# NJ  0.075758

# %%
# from the below plot we get to know that MA has the highest ratio=number of hospitals better/total number of hospitals and 
# thus has the best healthcare as far as Heart Failure Mortality is concerned. 
answers.plot()
plt.show()

# %%
#Now in MA, let's find out which hospitals have better rate than national rate
Hosp_compare_filter_MA = Hosp_compare_main[(Hosp_compare_main['Measure ID']=='MORT_30_HF') & (Hosp_compare_main['State']=='MA')]

# %%
Hosp_MA_better = Hosp_compare_filter_MA[Hosp_compare_filter_MA['Compared to National'] =='Better than the National Rate']
# in MA the below hospitals have better than the national rate

# %%
Hosp_MA_city_best= Hosp_MA_better.groupby('City')['Hospital Name'].count()
#From the below information we can conclude, Boston is the best city for Heart Failure Treatment
Hosp_MA_city_best
# Out:
# City
# BEVERLY        1
# BOSTON         5
# BRIGHTON       1
# BURLINGTON     1
# FALL RIVER     2
# FALMOUTH       1
# NEWTON         1
# SALEM          1
# SPRINGFIELD    1
# WINCHESTER     1
# WORCESTER      1
# Name: Hospital Name, dtype: int64

# %%
Hosp_MA_city_best.plot(kind='barh',color='red')
plt.show()

# %%
HospState_Mortality = hospital_state_1.loc[hospital_state_1['Measure ID'].isin(['MORT_30_AMI','MORT_30_HF','MORT_30_PN',
                                                                                'MORT_30_COPD','MORT_30_STK','MORT_30_CABG'])]

# %%
HospState_Mortality
# Out:
#     State                                       Measure Name    Measure ID  \
# 0      AK  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 1      AL  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 2      AR  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 3      AS  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 4      AZ  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 5      CA  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 6      CO  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 7      CT  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 8      DC  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 9      DE  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# 10     FL  Acute Myocardial Infarction (AMI) 30-Day Morta...   MORT_30_AMI
# ...

# %%
HospState_Worse = HospState_Mortality.groupby('State')['Number of Hospitals Worse'].agg('sum').sort_values(ascending=False).head(10)

# %%
HospState_Worse
# Out:
# State
# FL    49.0
# CA    38.0
# TN    30.0
# TX    29.0
# NC    29.0
# NY    23.0
# AR    22.0
# IL    22.0
# AL    21.0
# WA    21.0
# Name: Number of Hospitals Worse, dtype: float64

# %%
HospState_Worse.plot(kind='bar')

# %%
Total_no_of_hospital_filtered_1 = Total_no_hospital_in_a_state[['FL','CA','TN','TX','NC','NY','AR','IL','AL','WA']]
Total_no_of_hospital_filtered_1
# Out:
# State
# FL    187
# CA    343
# TN    107
# TX    410
# NC    107
# NY    171
# AR     75
# IL    180
# AL     91
# WA     91
# Name: Provider ID, dtype: int64

# %%
plt.show()

# %%
# find the state which has the higher number of hospitals who have better than the national rate for HIP/KNEE Complications
Hosp_comp_Knee = Hosp_compare_main[((Hosp_compare_main['Measure ID']=='COMP_HIP_KNEE') & (Hosp_compare_main['Compared to National']=='Better than the National Rate'))]

# %%
Hosp_comp_Knee
# Out:
#        Provider ID                                      Hospital Name  \
# 171          10019                     HELEN KELLER MEMORIAL HOSPITAL
# 399          10039                                HUNTSVILLE HOSPITAL
# 3705         40004                 WASHINGTON REGIONAL MEDICAL CENTER
# 4446         40147                         ARKANSAS SURGICAL HOSPITAL
# 5187         50013                                 ST HELENA HOSPITAL
# 6897         50195                                WASHINGTON HOSPITAL
# 7543         50290              PROVIDENCE SAINT JOHN'S HEALTH CENTER
# 7809         50324                 SCRIPPS MEMORIAL HOSPITAL LA JOLLA
# 8037         50357                     GOLETA VALLEY COTTAGE HOSPITAL
# 9538         50625                        CEDARS-SINAI MEDICAL CENTER
# 10507        50769                          HOAG ORTHOPEDIC INSTITUTE
# 11723        60010                             POUDRE VALLEY HOSPITAL
# ...

# %%
national_knee_rate = Hospital_national.loc[Hospital_national['Measure ID']=='COMP_HIP_KNEE']['National Rate']

# %%
national_knee_rate_list = list(national_knee_rate)
national_knee_rate_list
# Out:
# [2.7999999999999998]

# %%
Hosp_comp_Knee_State = Hosp_comp_Knee.groupby('State')['Provider ID'].count()
Hosp_comp_Knee_State
# Out:
# State
# AL    2
# AR    2
# CA    7
# CO    3
# CT    1
# DE    2
# FL    5
# GA    3
# IN    2
# KS    2
# MA    1
# MD    1
# MI    3
# MN    1
# MO    1
# NC    4
# NJ    2
# NY    3
# OH    5
# OK    1
# OR    1
# PA    2
# SC    1
# TN    1
# TX    5
# VA    2
# WA    2
# WI    1
# Name: Provider ID, dtype: int64

# %%
Hosp_comp_Knee_State.plot(kind='bar',color='pink')
plt.show()
#CA has the highest number of hospitals which are better than national average for KNEE/HIP related

# %%
Hosp_comp_Knee_better_worse = Hosp_compare_main[((Hosp_compare_main['Measure ID']=='COMP_HIP_KNEE') & (Hosp_compare_main['Compared to National']=='Better than the National Rate'))|((Hosp_compare_main['Measure ID']=='COMP_HIP_KNEE') & (Hosp_compare_main['Compared to National']=='Worse than the National Rate'))]

# %%
Hosp_comp_Knee_better_worse
# Out:
#        Provider ID                                      Hospital Name  \
# 0            10001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 171          10019                     HELEN KELLER MEMORIAL HOSPITAL
# 399          10039                                HUNTSVILLE HOSPITAL
# 418          10040                    GADSDEN REGIONAL MEDICAL CENTER
# 3705         40004                 WASHINGTON REGIONAL MEDICAL CENTER
# 4351         40118                      NEA BAPTIST MEMORIAL HOSPITAL
# 4446         40147                         ARKANSAS SURGICAL HOSPITAL
# 5187         50013                                 ST HELENA HOSPITAL
# 6897         50195                                WASHINGTON HOSPITAL
# 7543         50290              PROVIDENCE SAINT JOHN'S HEALTH CENTER
# 7809         50324                 SCRIPPS MEMORIAL HOSPITAL LA JOLLA
# 8037         50357                     GOLETA VALLEY COTTAGE HOSPITAL
# ...

# %%
Hosp_compare_count = Hosp_comp_Knee_better_worse.groupby('Compared to National')['Provider ID'].count()
Hosp_compare_count
# for HIP/KNEE no of hospitals better than national rate is greater than no of hospitals worse than national rate
# Out:
# Compared to National
# Better than the National Rate    66
# Worse than the National Rate     38
# Name: Provider ID, dtype: int64

# %%
#KNEE/HIP 
Hosp_compare_count.plot(kind='pie')
plt.show()
#According to the pie chart for KNEE/HIP complications, the hospitals better than national rate is more than the hospitals
#worse than national rate

# %%
Hosp_compare_main_Measure = Hosp_compare_main.groupby(['Measure ID'][['Compared to National']=='Better than the National Rate']).count()
