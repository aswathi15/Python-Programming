# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Terror = pd.read_excel("C://Users//Aswathi//Desktop//gtd.xlsx")

# %%
Terror.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170350 entries, 0 to 170349
# Columns: 135 entries, eventid to related
# dtypes: datetime64[ns](1), float64(53), int64(24), object(57)
# memory usage: 175.5+ MB

# %%
Terror.isnull()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# 5         False  False   False  False        True     False        True
# 6         False  False   False  False        True     False        True
# 7         False  False   False  False        True     False        True
# 8         False  False   False  False        True     False        True
# 9         False  False   False  False        True     False        True
# 10        False  False   False  False        True     False        True
# 11        False  False   False  False        True     False        True
# ...

# %%
ax = plt.figure(figsize = (12,6))
sns.heatmap(Terror.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
plt.show()

# %%
#Terror=Terror.drop('approxdate',axis=1)
#Terror=Terror.drop('resolution',axis=1)
#Terror = Terror.drop('alternative',axis=1)
#Terror = Terror.drop('alternative_txt',axis=1)
#Terror = Terror.drop('attacktype2',axis = 1)
#Terror = Terror.drop('attacktype2_txt',axis = 1)
#Terror = Terror.drop('attacktype3',axis = 1)
#Terror = Terror.drop('attacktype3_txt',axis = 1)
#Terror = Terror.drop('targtype2',axis = 1)
#Terror = Terror.drop('targtype2_txt',axis = 1)
#Terror = Terror.drop('targsubtype2',axis = 1)
#Terror = Terror.drop('targsubtype2_txt',axis = 1)
#Terror = Terror.drop('corp2',axis = 1)
#Terror = Terror.drop('target2',axis = 1)
#Terror = Terror.drop('natlty2',axis = 1)
#Terror = Terror.drop('natlty2_txt',axis = 1)
#Terror = Terror.drop('targtype3',axis = 1)
#Terror = Terror.drop('targtype3_txt',axis = 1)
#Terror = Terror.drop('targsubtype3',axis = 1)
#Terror = Terror.drop('targsubtype3_txt',axis = 1)
#Terror = Terror.drop('corp3',axis = 1)
#Terror = Terror.drop('target3',axis = 1)
#Terror = Terror.drop('natlty3',axis = 1)
#Terror = Terror.drop('natlty3_txt',axis = 1)
#Terror = Terror.drop('gsubname',axis = 1)
#Terror = Terror.drop('gname2',axis = 1)
#Terror = Terror.drop('gsubname2',axis = 1)
#Terror = Terror.drop('gname3',axis = 1)
#Terror = Terror.drop('gsubname3',axis = 1)
#Terror = Terror.drop('guncertain2',axis = 1)
#Terror = Terror.drop('guncertain3',axis = 1)
#Terror = Terror.drop('claimmode',axis = 1)
#Terror = Terror.drop('claimmode_txt',axis = 1)
#Terror = Terror.drop('claim2',axis = 1)
#Terror = Terror.drop('claimmode2',axis = 1)
#Terror = Terror.drop('claimmode2_txt',axis = 1)
#Terror = Terror.drop('claim3',axis = 1)
#Terror = Terror.drop('claimmode3',axis = 1)
#Terror = Terror.drop('claimmode3_txt',axis = 1)
#Terror = Terror.drop('compclaim',axis = 1)
#Terror = Terror.drop('weaptype2',axis = 1)
#Terror = Terror.drop('weaptype2_txt',axis = 1)
#Terror = Terror.drop('weapsubtype2',axis = 1)
#Terror = Terror.drop('weapsubtype2_txt',axis = 1)
#Terror = Terror.drop('weaptype3',axis = 1)
#Terror = Terror.drop('weaptype3_txt',axis = 1)
#Terror = Terror.drop('weapsubtype3',axis = 1)
#Terror = Terror.drop('weapsubtype3_txt',axis = 1)
#Terror = Terror.drop('weaptype4',axis = 1)
#Terror = Terror.drop('weaptype4_txt',axis = 1)
#Terror = Terror.drop('weapsubtype4',axis = 1)
#Terror = Terror.drop('weapsubtype4_txt',axis = 1)
#Terror = Terror.drop('nhostkid',axis = 1)
#Terror = Terror.drop('nhostkidus',axis = 1)
#Terror = Terror.drop('nhours',axis = 1)
#Terror = Terror.drop('ndays',axis = 1)
#Terror = Terror.drop('divert',axis = 1)
#Terror = Terror.drop('kidhijcountry',axis = 1)
#Terror = Terror.drop('ransomamtus',axis = 1)
#Terror = Terror.drop('ransompaid',axis = 1)
#Terror = Terror.drop('ransompaidus',axis = 1)
#Terror = Terror.drop('ransomnote',axis = 1)
#Terror = Terror.drop('hostkidoutcome',axis = 1)
#Terror = Terror.drop('hostkidoutcome_txt',axis = 1)
#Terror = Terror.drop('nreleased',axis = 1)
#Terror = Terror.drop('scite1',axis=1)
#Terror = Terror.drop('scite2',axis=1)
#Terror = Terror.drop('scite3',axis=1)
#Terror = Terror.drop('related',axis=1)

# %%
Terror.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170350 entries, 0 to 170349
# Data columns (total 66 columns):
# eventid             170350 non-null int64
# iyear               170350 non-null int64
# imonth              170350 non-null int64
# iday                170350 non-null int64
# extended            170350 non-null int64
# country             170350 non-null int64
# country_txt         170350 non-null object
# region              170350 non-null int64
# region_txt          170350 non-null object
# provstate           155848 non-null object
# city                169904 non-null object
# latitude            165744 non-null float64
# longitude           165744 non-null float64
# specificity         170346 non-null float64
# vicinity            170350 non-null int64
# location            47974 non-null object
# summary             104212 non-null object
# crit1               170350 non-null int64
# crit2               170350 non-null int64
# ...

# %%
ax = plt.figure(figsize = (12,6))
sns.heatmap(Terror.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
plt.show()

# %%
Terror.head(5)
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate   ...    propcomment  \
# 0       2  Central America & Caribbean       NaN   ...            NaN
# 1       1                North America       NaN   ...            NaN
# 2       5               Southeast Asia    Tarlac   ...            NaN
# 3       8               Western Europe    Attica   ...            NaN
# 4       4                    East Asia       NaN   ...            NaN
#
#    ishostkid  ransom  ransomamt  addnotes dbsource INT_LOG  INT_IDEO  \
# ...
